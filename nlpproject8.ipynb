# %%
# !pip install textblob wordcloud nltk -q

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from wordcloud import WordCloud

from nltk.corpus import stopwords
import string
import re

from textblob import TextBlob

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv("/content/Reviews.csv", engine="python", on_bad_lines="skip")

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221359 entries, 0 to 221358
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      221359 non-null  int64
#  1   ProductId               221359 non-null  object
#  2   UserId                  221359 non-null  object
#  3   ProfileName             221346 non-null  object
#  4   HelpfulnessNumerator    221359 non-null  int64
#  5   HelpfulnessDenominator  221359 non-null  int64
#  6   Score                   221359 non-null  int64
#  7   Time                    221359 non-null  int64
#  8   Summary                 221350 non-null  object
#  9   Text                    221359 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 16.9+ MB

# %%
df = df[['Score','Summary','Text']]

# %%
stop_words = set(stopwords.words('english'))

def clean_text(text):

    text = text.lower()

    text = re.sub(r"http\S+"," ",text)

    text = re.sub(r"[^a-zA-Z]"," ",text)

    words = text.split()

    words = [w for w in words if w not in stop_words]

    return " ".join(words)

df["Clean_Text"] = df["Text"].apply(clean_text)

# %%
def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    return "Neutral"

df["Sentiment"] = df["Clean_Text"].apply(get_sentiment)

# %%
df["Sentiment"].value_counts()
# Out:
# Sentiment
# Positive    194658
# Negative     22759
# Neutral       3942
# Name: count, dtype: int64

# %%
df["Sentiment"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    figsize=(6,6)
)

plt.title("Customer Sentiments")

plt.ylabel("")

plt.show()

# %%
text = " ".join(df["Clean_Text"])

wordcloud = WordCloud(
    width=800,
    height=400,
    background_color="white"
).generate(text)

plt.figure(figsize=(12,6))

plt.imshow(wordcloud)

plt.axis("off")

plt.show()

# %%
from collections import Counter

words = " ".join(df["Clean_Text"]).split()

counter = Counter(words)

common = counter.most_common(20)

common_df = pd.DataFrame(common, columns=["Word","Count"])

common_df
# Out:
#        Word   Count
# 0        br  257631
# 1      like  101426
# 2      good   78927
# 3       one   69711
# 4    coffee   68325
# 5     taste   67440
# 6     great   65150
# 7   product   59530
# 8    flavor   58160
# 9       tea   54591
# 10     food   52362
# 11    would   49513
# 12     love   49483
# 13      get   42594
# 14   really   39900
# 15     much   36911
# 16   amazon   34998
# 17     also   34165
# 18     time   33230
# 19      use   33054

# %%
common_df.plot(
    x="Word",
    y="Count",
    kind="bar",
    figsize=(10,5)
)

plt.title("Top 20 Frequent Words")

plt.show()
